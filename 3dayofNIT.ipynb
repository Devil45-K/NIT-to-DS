# %% [markdown]
# Data structure defines more than one value
# 2 types of data structure
# 1)inbuild-- list, tuple, set, dict
# 2)user defined-- stack, linked list, heap, tree(normally used by some libraries)

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
print(len(l))
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(50) #duplicate is allowed
l
# Out:
# [10, 20, 30, 40, 50, 50]

# %%
l.append(60,70,80) #only one argument can be append
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l.append(60,70,80)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l1 = []
l1.append('nit')
l1.append(1.2)
l1.append([1,2,3]) #this is nested list (list inside the list)
l1.append(True) 
l1.append(2+3j)
print(l1)
# Out:
# ['nit', 1.2, [1, 2, 3], True, (2+3j)]

# %%
l1.append('mit') #append add element at end in the list
print(l1)
# Out:
# ['nit', 1.2, [1, 2, 3], True, (2+3j), 'mit']

# %%
for i in l1:
    print(i)
# Out:
# nit
# 1.2
# [1, 2, 3]
# True
# (2+3j)
# mit

# %%
for i in enumerate(l1):  #enumerate capture indexes
    print(i)
# Out:
# (0, 'nit')
# (1, 1.2)
# (2, [1, 2, 3])
# (3, True)
# (4, (2+3j))
# (5, 'mit')

# %% [markdown]
# Index in python begines with 0
# Index can be divided into 3 types
# 1)Forward Indexing--left to right
# 2)Backward Indexing--right to left
# 3)Step Indexing--every step count jumps
# ':' called slice

# %%
l[:] #by default return overall list
# Out:
# [10, 20, 30, 40, 50, 50]

# %%
l[0] #Forward indexing starts from 0
# Out:
# 10

# %%
l[-3] #backward indexing strats from -1
# Out:
# 40

# %%
l
# Out:
# [10, 20, 30, 40, 50, 50]

# %%
l[6] # because it contains only 0 to 5 index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 l[6]
#
# IndexError: list index out of range

# %%
l[5]
# Out:
# 50

# %%
l[-7] #backward indexing but have only -1 to -6 indexs
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 l[-7]
#
# IndexError: list index out of range

# %%
l[-1]
# Out:
# 50

# %%
l[-6]
# Out:
# 10

# %%
#if want only 20, 30, 40
l[1:4] #0 to n-1
# Out:
# [20, 30, 40]

# %%
l[0:6]
# Out:
# [10, 20, 30, 40, 50, 50]

# %%
l[0:5]
# Out:
# [10, 20, 30, 40, 50]

# %%
l[0] =100  #list is mutable

# %%
l
# Out:
# [100, 20, 30, 40, 50, 50]

# %%
l[-6:-1]
# Out:
# [100, 20, 30, 40, 50]

# %% [markdown]
# Data Structure

# %%
l
# Out:
# [100, 20, 30, 40, 50, 50]

# %%
l1 = l.copy() #copy() is use to copy a data structure
print(l1)
print(l)
# Out:
# [100, 20, 30, 40, 50, 50]
# [100, 20, 30, 40, 50, 50]

# %%
id(l) #id() use to find memory location of the variable
# Out:
# 1865776968000

# %%
len(l)
# Out:
# 6

# %%
l.count(20) #helps to count functions
# Out:
# 1

# %%
l.append([77, 88, 99]) #list inside list
l
# Out:
# [100, 20, 30, 40, 50, 50, [77, 88, 99]]

# %%
l1.clear() #remove elements inside list
l1
# Out:
# []

# %%
l3 = [10, 20, 30, 40, 50]
l3
# Out:
# [10, 20, 30, 40, 50]

# %%
l3.pop(3) #remove elements with the help of index
# Out:
# 40

# %%
l3
# Out:
# [10, 20, 30, 50]

# %%
l3.remove(30) #removes element with help of element self
l3
# Out:
# [10, 20, 50]

# %%
l3.index(20) #returns index using element
# Out:
# 1

# %%
l4 = [12, 13, 14, 15]
l4
# Out:
# [12, 13, 14, 15]

# %%
l4.pop() #by defaut removes last element in list
l4
# Out:
# [12, 13]

# %%
del l4 #remove entier list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 del l4
#
# NameError: name 'l4' is not defined
