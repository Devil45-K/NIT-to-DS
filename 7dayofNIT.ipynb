# %%
2 + 4 #addition
# Out:
# 6

# %%
4 - 2 #substraction
# Out:
# 2

# %%
4 * 2 #multiplication
# Out:
# 8

# %%
8 / 4 #division
# Out:
# 2.0

# %%
8 // 4 #int division
# Out:
# 2

# %%
5 + 5 * 5
# Out:
# 30

# %%
(5 * 2)- 5 #BODMAS Rule
# Out:
# 5

# %%
5 - 3 + #syntax error
# Out:
#   Cell In[8], line 1
#     5 - 3 + #syntax error
#             ^
# SyntaxError: invalid syntax

# %%
True/True
# Out:
# 1.0

# %%
False/True
# Out:
# 0.0

# %%
True/False #runtime error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
2 ** 3 #power
# Out:
# 8

# %%
15 % 2 #modulus
# Out:
# 1

# %%
15 %% 2
# Out:
#   Cell In[14], line 1
#     15 %% 2
#         ^
# SyntaxError: invalid syntax

# %%
a,b,c,d,e = 10,3.14,'nit',2+3j,True
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 10
# 3.14
# nit
# (2+3j)
# True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %% [markdown]
# *Lets Work With String*

# %%
'JJCC'
# Out:
# 'JJCC'

# %%
print('JJCC')
# Out:
# JJCC

# %%
'Vedantu'
# Out:
# 'Vedantu'

# %%
a = 5
b = 'JJCC'
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 a = 5
#       2 b = 'JJCC'
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print('Vibrant Mindes's'Technology')
# Out:
#   Cell In[21], line 1
#     print('Vibrant Mindes's'Technology')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Vibrant Mindes's Technology")
# Out:
# Vibrant Mindes's Technology

# %%
print('Vibrant Mindes\'s"Technology"')
# Out:
# Vibrant Mindes's"Technology"

# %%
print('Vibrant Mindes','Technology')
# Out:
# Vibrant Mindes Technology

# %%
'jjcc' + 'jjcc' #add jjcc to jjcc
# Out:
# 'jjccjjcc'

# %%
'jjcc' 'jjcc'
# Out:
# 'jjccjjcc'

# %%
#print jjcc 5 times
5 * 'jjcc'
# Out:
# 'jjccjjccjjccjjccjjcc'

# %%
10 * ' jjcc' #space between words
# Out:
# ' jjcc jjcc jjcc jjcc jjcc jjcc jjcc jjcc jjcc jjcc'

# %% [markdown]
# # Variable || identifier || objects

# %%
2
# Out:
# 2

# %%
x = 5 #x is variable/identifier/object and 5 is value
x
# Out:
# 5

# %%
x + 3
# Out:
# 8

# %%
y = 3
x + y
# Out:
# 8

# %%
x = 9

# %%
x + y
# Out:
# 12

# %%
x + 10
# Out:
# 19

# %%
y
# Out:
# 3

# %%
_ + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 _ + y
#
# TypeError: can only concatenate str (not "int") to str

# %%
#string variables
name = 'Robin'

# %%
name
# Out:
# 'Robin'

# %%
name + 'RJ'
# Out:
# 'RobinRJ'

# %%
name + ' RJ'
# Out:
# 'Robin RJ'

# %%
name 'RJ'
# Out:
#   Cell In[46], line 1
#     name 'RJ'
#          ^
# SyntaxError: invalid syntax

# %%
name
# Out:
# 'Robin'

# %%
len(name)
# Out:
# 5

# %%
name[0]
# Out:
# 'R'

# %%
name[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 name[5]
#
# IndexError: string index out of range

# %%
name[-2]
# Out:
# 'i'

# %%
name
# Out:
# 'Robin'

# %%
name[0:1] = 'M' #str is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 name[0:1] = 'M'
#
# TypeError: 'str' object does not support item assignment

# %%
name[1:]
# Out:
# 'obin'

# %%
'M' + name[1:] #Robin changes to Mobin
# Out:
# 'Mobin'

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
# help>  list
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
# ...

# %%
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      MonthDayNano
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
# ...

# %% [markdown]
# # introduction to ID

# %%
#variable address
num = 5
id(num)
# Out:
# 140728562231864

# %%
name = 'Aura'
id(name) #Addresses are different for both
# Out:
# 1330835844928

# %%
a = 10
id(a)
# Out:
# 140728562232024

# %%
b = a
id(b) #pyhton is more memory efficient
# Out:
# 140728562232024

# %% [markdown]
# # There is no concept called constant in python

# %%
PI = 3.14
PI
# Out:
# 3.14

# %%
PI = 12.5
PI
# Out:
# 12.5

# %% [markdown]
# # Pyhon Operators

# %% [markdown]
# ## Arithmetic Operators +,-,*,/,**,//,%

# %%
x, y = 10,15

# %%
x + y
# Out:
# 25

# %%
x - y
# Out:
# -5

# %%
x * y
# Out:
# 150

# %%
x / y
# Out:
# 0.6666666666666666

# %%
x // y
# Out:
# 0

# %%
x ** 2
# Out:
# 100

# %%
x % y
# Out:
# 10

# %%
5 ** 2
# Out:
# 25

# %% [markdown]
# ## Assignment Operator +=, -=, *=, /=, //=

# %%
x1 = 2

# %%
x1 = x1 + 2

# %%
x1
# Out:
# 4

# %%
x1 += 2

# %%
x1
# Out:
# 6

# %%
x1 +=2

# %%
x1
# Out:
# 8

# %%
x1 -= 2
x1
# Out:
# 6

# %%
x1 *= 2
x1
# Out:
# 12

# %%
x1 /= 3

# %%
x1
# Out:
# 4.0

# %%
x1 //= 3
x1
# Out:
# 1.0

# %% [markdown]
# ## Unary Operator

# %%
n = 7

# %%
m = -(n)

# %%
m
# Out:
# -7

# %%
n
# Out:
# 7

# %% [markdown]
# ## Relational Operators ==, <, >, <=, >=, !=

# %%
a = 5
b = 7

# %%
a == b #a = b #we cann't use = operator that means assigning
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# ## Logical Operator

# %%
a = 5
b = 7

# %%
a < 6 and b>a
# Out:
# True

# %%
a>4 and b>8
# Out:
# False

# %%
a<6 or b<6
# Out:
# True

# %%
not x
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x #use to reverse the operation
# Out:
# True

# %% [markdown]
# ## Number System Conversion

# %% [raw]
# Binary(base-2) 0-1  0b
# Octal(base-8) 0-7   0o
# Decimal(base-10) 0-9   0x
# Hexadecimal(base-16) 0-9 a-f   0x

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(19)
# Out:
# '0o23'

# %%
bin(26)
# Out:
# '0b11010'

# %%
oct(25)
# Out:
# '0o31'

# %%
hex(119)
# Out:
# '0x77'

# %%
int(0x77)
# Out:
# 119

# %% [markdown]
# ## Bitwise Operator
# * COMPLEMENT (~) || AND (&) || OR (|) || XOR (^) || LEFT SHIFT (<<) || RIGHT SHIFT (>>)

# %%
# Complement (~)
~12 #we get -13. cause didn't print negative value in memory(by using ~ can store indirectly)
# Out:
# -13

# %%
~-5 #complementry logic -5s complement + 1
# Out:
# 4

# %%
~77 #logic 77s coplement + 1
# Out:
# -78

# %%
#AND &
12 & 15 #AND of (12,15)
# Out:
# 12

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(15)
# Out:
# '0b1111'

# %%
#OR |
13 | 17 #OR of (13,17)
# Out:
# 29

# %%
bin(13)
# Out:
# '0b1101'

# %%
bin(17)
# Out:
# '0b10001'

# %%
# XOR ^ #1-1=0, 0-0=0 otherwise 1
10 ^ 13
# Out:
# 7

# %%
print(bin(10))
print(bin(13))
0b1010^0b1101
# Out:
# 0b1010
# 0b1101
# 7

# %%
12 ^ 13
# Out:
# 1

# %%
25^30
# Out:
# 7

# %%
#BIT WISE LEFT SHIFT OPERATOR <<
#by default you will take two zeros
#bin(3)=0b11 \ also can say 1100
3<<2
# Out:
# 12

# %%
bin(3)
# Out:
# '0b11'

# %%
#RIGHT SHIFT (NEED TO LOSS BIT)
#if bin(10)=1010 loss last 2 bits

# %%
10>>2
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %%
12>>2
# Out:
# 3

# %% [markdown]
# ## MATH MODULE IN PYTHON
# * Package is collection of module
# * Module is collection of functions
# * functions are inbuilt and user de
# *

# %%
x = sqrt(9) #sqrt is builtin function #error because need to import math
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x = sqrt(9)
#
# NameError: name 'sqrt' is not defined

# %%
import math #math is module

# %%
x = math.sqrt(9) #sqrt- square root of value
x
# Out:
# 3.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(5.9)) #floor- minimum or least value
# Out:
# 5

# %%
print(math.ceil(5.4)) #ceil-maximum or higest value
# Out:
# 6

# %%
print(math.pow(3,3)) #pow(value,power)
# Out:
# 27.0

# %%
print(math.pi) #pi-constant
# Out:
# 3.141592653589793

# %%
print(math.e)#e- constant
# Out:
# 2.718281828459045

# %%
import math as m #no need to write math.sqrt you can m.sqrt
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt,pow #when ever want to call only a specific function we can use from
print(pow(12,2))
print(sqrt(144))
# Out:
# 144.0
# 12.0

# %%
from math import * # import * all funcion are called 
print(sqrt(81))
print(floor(5.9))
# Out:
# 9.0
# 5

# %%
round(pow(2,3)) #when ever we apply round function decimal will goan
# Out:
# 8

# %% [markdown]
# ## Input function

# %%
x = input()
y = input()
z = x+y
print(z)
#console waiting for user enter input
#by default input() considerate the input as string
# Out:
#  2
#  3
# 23

# %%
x1 = int(input('Enter 1st Value:'))
y1 = int(input('Enter 2nd Value:'))
print(x1+y1)
# Out:
# Enter 1st Value: 5
# Enter 2nd Value: 6
# 11

# %%
z1 = input()
print(z1)
# Out:
#  SitaRam
# SitaRam

# %%
print(z1[0])
# Out:
# S

# %%
print(z1[1])
# Out:
# i

# %%
print(z1[2])
# Out:
# t

# %%
ch = input('enter an expre:')
print(ch) #if you enter 2+6-4 you will get 2+6-4
# Out:
# enter an expre: 2+6-4
# 2+6-4

# %%
#to solve this problrm eval(input()) use
ch = eval(input('enter an expre:'))
print(ch)
# Out:
# enter an expre: 2+3-9
# -4
