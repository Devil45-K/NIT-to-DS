# %% [raw]
# 1: Basic of Python (Working with Numbers And Operator)

# %% [raw]
# **Arithmatic Operators (+,-,*,/,//,**,%)**

# %%
9
# Out:
# 9

# %%
9+9  #Addition
# Out:
# 18

# %%
9-9  #substraction
# Out:
# 0

# %%
9*9  #multiplication
# Out:
# 81

# %%
9/9  #float dividation
# Out:
# 1.0

# %%
9//9  #int division
# Out:
# 1

# %%
2**3  #Power
# Out:
# 8

# %%
(3*6)-8+3  #Playing with BODMAS
# Out:
# 13

# %%
3*6-(8+3)  #BODMAS
# Out:
# 7

# %%
9%9  #MODULE
# Out:
# 0

# %% [markdown]
# **Comparison Operators (<,>,==,!=,>=,<=)

# %%
3<5  #less than
# Out:
# True

# %%
3>5  #greater than
# Out:
# False

# %%
3==5  #equal to
# Out:
# False

# %%
3!=5  #not equal to
# Out:
# True

# %%
3<=5  #less than or equal to
# Out:
# True

# %%
3>=5  #greater than or equal to
# Out:
# False

# %% [markdown]
# 2:Working With Text
# text = String

# %%
Welcome to Devils Kitchen  #Err bcoz of not written in quotes
# Out:
#   Cell In[18], line 1
#     Welcome to Devils Kitchen
#             ^
# SyntaxError: invalid syntax

# %%
'Welcome to Devils Kitchen'  #String using single quot
# Out:
# 'Welcome to Devils Kitchen'

# %%
"Welcome to Devils Kitchen"  #String using Double quot
# Out:
# 'Welcome to Devils Kitchen'

# %%
'''Welcome to Devils Kitchen'''  #String using triple quot
# Out:
# 'Welcome to Devils Kitchen'

# %%
'Welcome 
to 
Devils Kitchen'  #Err bcoz of multi line strg isn't written in sinle quotes
# Out:
#   Cell In[22], line 1
#     'Welcome
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
''Welcome 
to 
Devils Kitchen''  #Err bcoz of multi line strg isn't written in double quotes
# Out:
#   Cell In[23], line 1
#     ''Welcome to Devils Kitchen''
#       ^
# SyntaxError: invalid syntax

# %%
'''Welcome
to Devils
Kitchen'''  #Here we can use triple qoute for multi line quote
# Out:
# 'Welcome\nto Devils\nKitchen'

# %% [markdown]
# Python Variables
# (variables = identifiers = objects)

# %%
a = 5 #(varibale = value)
a
# Out:
# 5

# %%
1 = v #variable can not start with number
1
# Out:
#   Cell In[2], line 1
#     1 = v #
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
AIzaSyCiRWKGg0_UWuPIH6KsNOLMWrJQisFli94
