# %% [markdown]
# TUPLE

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (10,20,30,40,10) #defines in () And duplicates are allowed
t1
# Out:
# (10, 20, 30, 40, 10)

# %%
t1.append(10) #only count() & index() allowed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t1.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.count(10) #counts by ements
# Out:
# 2

# %%
t1.index(20) #return index by element
# Out:
# 1

# %%
t2 = t1.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t2 = t1.copy()
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %%
t2 = (1234, 'pan abcde1234f', 2423) #mostly used in banking system
t2
# Out:
# (1234, 'pan abcde1234f', 2423)

# %%
t1[2]
# Out:
# 30

# %%
t1[-1]
# Out:
# 10

# %%
t1[1] = 100 #unmutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t1[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t3 = ([12,13],20,25) #list inside tuple allowed

# %%
t3
# Out:
# ([12, 13], 20, 25)

# %%
len(t3)
# Out:
# 3

# %% [markdown]
# ---------------------
